# %% [markdown]
# <a href="https://colab.research.google.com/github/alialexandra/AMLCV/blob/master/week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Task 3: Programming Image Segmentation
# This task is designed to get you started working with images in Python. Please feel free to use opencv or other frameworks. (Note that there are different solutions.)
#
# 1. Read and display the image *heavy.jpg*.
#
# 2. Convert image to RGB. (Only if necessary, i.e. depending on the choices made in the previous task you can omit this step.)
#
# 3. Convert the RGB image to grayscale.
#
# 4. Display the gray image.
# 5. Compute and display a histogram of the grayscale image. Try at least 2 (or more) different number of bins or bin width. Describe what you see.
# 6. We now aim to segment the white letters and digits. For this purpose: Define the lower and upper bounds for the values that you want to segment.
# 7. Retrieve a binary mask. It must have the same width and height as the original image, and should have the value 255 (white) for pixels within the range and 0 (black) for pixels outside the range.
# 8. Display the result. (Feel free to adapt the values, and save different results. It does not need to be perfect.)
# 9. Describe what you need to be adapt if you wish to segment colours from the RGB image.
# 10. You goal is to segment the yellow colour from the image. Try at least 3 different thresholds in RGB, and save your results. How well does it work?

# %%
# a) Read and display the image

# /content/heavy.jpg

import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread("/content/heavy.jpg")
plt.imshow(img)

# %%
# b) convert to RGB as openCV loads as BGR

img_convert_RGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img_convert_RGB)

# %%
# c) Convert the RGB image to grayscale.

img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(img_grey)

# %%
# e) Histogram with different bins
plt.hist(img_gray.ravel(), bins=32, color='blue', alpha=0.7)
plt.title("Histogram with 32 bins")
plt.show()

plt.hist(img_gray.ravel(), bins=256, color='green', alpha=0.7)
plt.title("Histogram with 256 bins")
plt.show()

# %%
# f) White segmentation (letters/digits)
lower_white, upper_white = 200, 255
mask_white = cv2.inRange(img_gray, lower_white, upper_white)

plt.imshow(mask_white, cmap='gray')
plt.title("White Segmentation")
plt.axis("off")
plt.show()

# i) Yellow segmentation in RGB
# (better would be HSV, but let’s try RGB first)
lower_yellow1 = np.array([150, 150, 0])
upper_yellow1 = np.array([255, 255, 120])
mask_yellow1 = cv2.inRange(img_convert_RGB, lower_yellow1, upper_yellow1)

lower_yellow2 = np.array([100, 100, 0])
upper_yellow2 = np.array([255, 255, 150])
mask_yellow2 = cv2.inRange(img_convert_RGB, lower_yellow2, upper_yellow2)

lower_yellow3 = np.array([180, 180, 0])
upper_yellow3 = np.array([255, 255, 130])
mask_yellow3 = cv2.inRange(img_convert_RGB, lower_yellow3, upper_yellow3)

# Display yellow results
fig, axs = plt.subplots(1, 3, figsize=(15, 5))
axs[0].imshow(mask_yellow1, cmap='gray'); axs[0].set_title("Threshold 1")
axs[1].imshow(mask_yellow2, cmap='gray'); axs[1].set_title("Threshold 2")
axs[2].imshow(mask_yellow3, cmap='gray'); axs[2].set_title("Threshold 3")
for ax in axs: ax.axis("off")
plt.show()

# %% [markdown]
# # Secțiune nouă
